# %%
import numpy as np
import matplotlib.pyplot as plt
import mne
import pandas as pd
import os

from sklearn.decomposition import PCA
import scipy
from mne.decoding import CSP

from mpl_toolkits.axes_grid1 import make_axes_locatable, ImageGrid
from matplotlib import cm
from colorspacious import cspace_converter
from collections import OrderedDict
from mne.cov import _regularized_covariance, compute_whitener

# %%
# %matplotlib auto
# %matplotlib auto

# %%
def augmentation_ampl(dfs, vac):
    for i in dfs.keys():
        for ind in range(len(dfs[i])):
            peak = i.split("_")[1]
            name = str(int(dfs[i].iloc[ind][0]))
            if len(name) == 1:
                name = "0"+name
            print(name)
            amplitude_peak = dfs[i].iloc[ind][1]
            print(amplitude_peak)
            if name not in vac.keys():
                vac[name] = {}
                vac[name][peak] = amplitude_peak
            else:
                vac[name][peak] = amplitude_peak
            print(vac)
    return vac

# %%
# ВЫ ВСЕ ПИДОРАСЫ, А Я У МАМЫ ХОРОШИЙ

# %%
def augmentation_time(dfs, vac):
    for i in dfs.keys():
        for ind in range(len(dfs[i])):
            peak = i.split("_")[1]
            name = str(int(dfs[i].iloc[ind][0]))
            if len(name) == 1:
                name = "0"+name
            time_peak = dfs[i].iloc[ind][1]
            if (int(time_peak*1000))%2 == 1:
                time_peak +=0.001
            if name not in vac.keys():
                vac[name] = {}
                vac[name][peak] = time_peak
            else:
                vac[name][peak] = time_peak
    return vac

# %%
a = pd.ExcelFile(r"C:\Users\artem\Downloads\AMPLITUDES_LATENCY(2).xlsx") # import table with latencys
sheet_names = a.sheet_names
latens_no = [name for name in sheet_names if "LATEN" in name and "NO" in name]
latens_yes = [name for name in sheet_names if "LATEN" in name and "YES" in name]
amplitudes_no = [name for name in sheet_names if "AMPL" in name and "NO" in name]
amplitudes_yes = [name for name in sheet_names if "AMPL" in name and "YES" in name]
dfs_no = {sheet: pd.read_excel(a, sheet, header = 1,names = None) for sheet in latens_no}
dfs_yes = {sheet: pd.read_excel(a, sheet, header = 1,names = None) for sheet in latens_yes}
dfs_ampl_no = {sheet: pd.read_excel(a, sheet, header = 1,names = None) for sheet in amplitudes_no}
dfs_ampl_yes = {sheet: pd.read_excel(a, sheet, header = 1,names = None) for sheet in amplitudes_yes}
t_no = {}
t_yes = {}
ampl_no = {}
ampl_yes = {}
t_no = augmentation_time(dfs_no, t_no)
t_yes = augmentation_time(dfs_yes, t_yes)
ampl_no = augmentation_ampl(dfs_ampl_no, ampl_no)
ampl_yes = augmentation_ampl(dfs_ampl_yes, ampl_yes)

# %%
def peaks_4_sex(evoked, ch, times):
    evoked_new = evoked.copy()
    evoked_4_ch = evoked.get_data()[evoked.ch_names.index(ch)]
    evoked_crop = evoked_4_ch[times-20: times+20]
    latency = np.argmax(evoked_crop)+times-20
    amplitude = np.max(evoked_crop)
    return latency, amplitude

# %%
def peaks_4_no_sex(evoked, ch, times):
    evoked_new = evoked.copy()
    evoked_4_ch = evoked_new.get_data()[epoch.ch_names.index(ch)]
    evoked_crop = evoked_4_ch[times-20: times+20]
    latency = np.argmin(evoked_crop)+times-20
    amplitude = np.min(evoked_crop)
    return latency, amplitude

# %%
def time (times,win):
    if win*1000%2 == 1:
        win+=0.001
    win = round(win, ndigits=4)
    print(win)
    time = np.where(times==win)
    print(time)
    times_new = time[0][0] 
    return times_new

# %%
data_dict = {}
timing = {}
conditions = ["yes", "no"]
for a,b,c in os.walk("D:\epochs_4_augmentation"):
    for path in c:
        sname = path.split("_")[-1].split(".")[-2]
        path_2_epoch = a+"\\"+path
        epoch = mne.read_epochs(path_2_epoch, preload = True)
        evoked = {c:epoch[c].average() for c in conditions}
        t = evoked["yes"].times
        peaks_times_no = t_no[sname]
        peaks_times_yes = t_yes[sname]
        peaks_ampls_no = t_no[sname]
        peaks_ampls_yes = t_yes[sname]
        if sname not in timing.keys():
            timing[sname] = {"yes":{}, "no":{}}
            data_dict[sname] = {"yes":{}, "no":{}}
        for peak in peaks_ampls_no.keys():
            times_no = time(t, peaks_times_no[peak])
            times_yes = time(t, peaks_times_yes[peak])
            timing[sname]["yes"][peak] = times_yes
            timing[sname]["no"][peak] = times_no
        for cond in evoked.keys():
            evoked_chs = evoked[cond]
            print(cond)
            if cond == "no":
                print(evoked_chs)
                for ch in evoked_chs.ch_names:
                    data_dict[sname][cond][ch] = {}
                    times_early, amplitudes_early = peaks_4_sex(evoked_chs, ch, timing[sname][cond]["EARLY"])
                    times_negative, amplitudes_negative = peaks_4_no_sex(evoked_chs, ch,
                                                                         timing[sname][cond]["NEGATIVE"])
                    times_late, amplitudes_late = peaks_4_sex(evoked_chs, ch, timing[sname][cond]["LATE"])
                    data_dict[sname][cond][ch] = {"EARLY AMPL":amplitudes_early, "EARLY LATEN":times_early,
                                             "NEGATIVE AMPL":amplitudes_negative, "NEGATIVE LATEN":times_negative,
                                             "LATE AMPL":amplitudes_late, "LATE LATEN":times_late}
            else:
                for ch in evoked_chs.ch_names:
                    data_dict[sname][cond][ch] = {}
                    times_early, amplitudes_early = peaks_4_sex(evoked_chs, ch, timing[sname][cond]["EARLY"])
                    times_negative, amplitudes_negative = peaks_4_sex(evoked_chs, ch,
                                                                      timing[sname][cond]["NEGATIVE"])
                    times_late, amplitudes_late = peaks_4_sex(evoked_chs, ch, timing[sname][cond]["LATE"])
                    data_dict[sname][cond][ch] = {"EARLY AMPL":amplitudes_early, "EARLY LATEN":times_early,
                                              "NEGATIVE AMPL":amplitudes_negative, "NEGATIVE LATEN":times_negative,
                                              "LATE AMPL":amplitudes_late, "LATE LATEN":times_late}

# %%
ref_fz_dict = {}
for name in data_dict.keys():
    if name not in ref_fz_dict.keys():
        ref_fz_dict[name] = {}
    for condition in data_dict[sname].keys():
        if condition not in ref_fz_dict[name].keys():
            ref_fz_dict[name][condition] = {}
        ref_ch = data_dict[sname][condition]["Fz"]
        time_average_ref = ref_ch["EARLY LATEN"]+ref_ch["NEGATIVE LATEN"]+ref_ch["LATE LATEN"]/3
        print("______________")
        print(time_average_ref)
        ampl_early_ref = ref_ch["EARLY AMPL"]
        ampl_neg_ref = ref_ch["NEGATIVE AMPL"]
        ampl_late_ref = ref_ch['LATE AMPL']
        for ch in data_dict[name][condition].keys():
            data_ch = data_dict[sname][condition][ch]
            time_average = data_ch["EARLY LATEN"]+data_ch["NEGATIVE LATEN"]+data_ch["LATE LATEN"]/3
            time_diff = int(time_average_ref - time_average)
            ampl_early_ch = data_ch["EARLY AMPL"]
            ampl_neg_ch = data_ch["NEGATIVE AMPL"]
            ampl_late_ch = data_ch["LATE AMPL"]
            ampl_early_diff = ampl_early_ch/ampl_early_ref
            ampl_neg_diff = ampl_neg_ch/ampl_neg_ref
            ampl_late_diff = ampl_late_ch/ampl_late_ref
            print(time_average)
            print("--------")
            ref_fz_dict[name][condition][ch] = {"TIME DIFF":time_diff,"TIME EARLY":round(data_ch["EARLY LATEN"], ndigits = 0),
                                                "TIME NEGATIVE":round(data_ch["NEGATIVE LATEN"]),
                                                "TIME LATE":round(data_ch["LATE LATEN"], ndigits = 0), "AMPL EARLY":ampl_early_diff, 
                                               "AMPL NEGATIVE": ampl_neg_diff, "AMPL LATE":ampl_late_diff}

# %%
ref_cz_dict = {}
for name in data_dict.keys():
    if name not in ref_cz_dict.keys():
        ref_cz_dict[name] = {}
    for condition in data_dict[sname].keys():
        if condition not in ref_cz_dict[name].keys():
            ref_cz_dict[name][condition] = {}
        ref_ch = data_dict[sname][condition]["Cz"]
        time_average_ref = ref_ch["EARLY LATEN"]+ref_ch["NEGATIVE LATEN"]+ref_ch["LATE LATEN"]/3
        print("______________")
        print(time_average_ref)
        ampl_early_ref = ref_ch["EARLY AMPL"]
        ampl_neg_ref = ref_ch["NEGATIVE AMPL"]
        ampl_late_ref = ref_ch['LATE AMPL']
        for ch in data_dict[name][condition].keys():
            data_ch = data_dict[sname][condition][ch]
            time_average = data_ch["EARLY LATEN"]+data_ch["NEGATIVE LATEN"]+data_ch["LATE LATEN"]/3
            time_diff = int(time_average_ref - time_average)
            ampl_early_ch = data_ch["EARLY AMPL"]
            ampl_neg_ch = data_ch["NEGATIVE AMPL"]
            ampl_late_ch = data_ch["LATE AMPL"]
            ampl_early_diff = ampl_early_ch/ampl_early_ref
            ampl_neg_diff = ampl_neg_ch/ampl_neg_ref
            ampl_late_diff = ampl_late_ch/ampl_late_ref
            print(time_average)
            print("--------")
            ref_cz_dict[name][condition][ch] = {"TIME DIFF":time_diff,"TIME EARLY":round(data_ch["EARLY LATEN"], ndigits = 0),
                                                "TIME NEGATIVE":round(data_ch["NEGATIVE LATEN"]),
                                                "TIME LATE":round(data_ch["LATE LATEN"], ndigits = 0), "AMPL EARLY":ampl_early_diff, 
                                               "AMPL NEGATIVE": ampl_neg_diff, "AMPL LATE":ampl_late_diff}

# %%
ref_pz_dict = {}
for name in data_dict.keys():
    if name not in ref_pz_dict.keys():
        ref_pz_dict[name] = {}
    for condition in data_dict[sname].keys():
        if condition not in ref_pz_dict[name].keys():
            ref_pz_dict[name][condition] = {}
        ref_ch = data_dict[sname][condition]["Pz"]
        time_average_ref = ref_ch["EARLY LATEN"]+ref_ch["NEGATIVE LATEN"]+ref_ch["LATE LATEN"]/3
        print("______________")
        print(time_average_ref)
        ampl_early_ref = ref_ch["EARLY AMPL"]
        ampl_neg_ref = ref_ch["NEGATIVE AMPL"]
        ampl_late_ref = ref_ch['LATE AMPL']
        for ch in data_dict[name][condition].keys():
            data_ch = data_dict[sname][condition][ch]
            time_average = data_ch["EARLY LATEN"]+data_ch["NEGATIVE LATEN"]+data_ch["LATE LATEN"]/3
            time_diff = int(time_average_ref - time_average)
            ampl_early_ch = data_ch["EARLY AMPL"]
            ampl_neg_ch = data_ch["NEGATIVE AMPL"]
            ampl_late_ch = data_ch["LATE AMPL"]
            ampl_early_diff = ampl_early_ch/ampl_early_ref
            ampl_neg_diff = ampl_neg_ch/ampl_neg_ref
            ampl_late_diff = ampl_late_ch/ampl_late_ref
            print(time_average)
            print("--------")
            ref_pz_dict[name][condition][ch] = {"TIME DIFF":time_diff,"TIME EARLY":round(data_ch["EARLY LATEN"], ndigits = 0),
                                                "TIME NEGATIVE":round(data_ch["NEGATIVE LATEN"]),
                                                "TIME LATE":round(data_ch["LATE LATEN"], ndigits = 0), "AMPL EARLY":ampl_early_diff, 
                                               "AMPL NEGATIVE": ampl_neg_diff, "AMPL LATE":ampl_late_diff}

# %%
ref_FC1_dict = {}
for name in data_dict.keys():
    if name not in ref_FC1_dict.keys():
        ref_FC1_dict[name] = {}
    for condition in data_dict[sname].keys():
        if condition not in ref_FC1_dict[name].keys():
            ref_FC1_dict[name][condition] = {}
        ref_ch = data_dict[sname][condition]["FC1"]
        time_average_ref = ref_ch["EARLY LATEN"]+ref_ch["NEGATIVE LATEN"]+ref_ch["LATE LATEN"]/3
        print("______________")
        print(time_average_ref)
        ampl_early_ref = ref_ch["EARLY AMPL"]
        ampl_neg_ref = ref_ch["NEGATIVE AMPL"]
        ampl_late_ref = ref_ch['LATE AMPL']
        for ch in data_dict[name][condition].keys():
            data_ch = data_dict[sname][condition][ch]
            time_average = data_ch["EARLY LATEN"]+data_ch["NEGATIVE LATEN"]+data_ch["LATE LATEN"]/3
            time_diff = int(time_average_ref - time_average)
            ampl_early_ch = data_ch["EARLY AMPL"]
            ampl_neg_ch = data_ch["NEGATIVE AMPL"]
            ampl_late_ch = data_ch["LATE AMPL"]
            ampl_early_diff = ampl_early_ch/ampl_early_ref
            ampl_neg_diff = ampl_neg_ch/ampl_neg_ref
            ampl_late_diff = ampl_late_ch/ampl_late_ref
            print(time_average)
            print("--------")
            ref_FC1_dict[name][condition][ch] = {"TIME DIFF":time_diff,"TIME EARLY":round(data_ch["EARLY LATEN"], ndigits = 0),
                                                "TIME NEGATIVE":round(data_ch["NEGATIVE LATEN"]),
                                                "TIME LATE":round(data_ch["LATE LATEN"], ndigits = 0), "AMPL EARLY":ampl_early_diff, 
                                               "AMPL NEGATIVE": ampl_neg_diff, "AMPL LATE":ampl_late_diff}

# %%
ref_FC2_dict = {}
for name in data_dict.keys():
    if name not in ref_FC2_dict.keys():
        ref_FC2_dict[name] = {}
    for condition in data_dict[sname].keys():
        if condition not in ref_FC2_dict[name].keys():
            ref_FC2_dict[name][condition] = {}
        ref_ch = data_dict[sname][condition]["FC2"]
        time_average_ref = ref_ch["EARLY LATEN"]+ref_ch["NEGATIVE LATEN"]+ref_ch["LATE LATEN"]/3
        print("______________")
        print(time_average_ref)
        ampl_early_ref = ref_ch["EARLY AMPL"]
        ampl_neg_ref = ref_ch["NEGATIVE AMPL"]
        ampl_late_ref = ref_ch['LATE AMPL']
        for ch in data_dict[name][condition].keys():
            data_ch = data_dict[sname][condition][ch]
            time_average = data_ch["EARLY LATEN"]+data_ch["NEGATIVE LATEN"]+data_ch["LATE LATEN"]/3
            time_diff = int(time_average_ref - time_average)
            ampl_early_ch = data_ch["EARLY AMPL"]
            ampl_neg_ch = data_ch["NEGATIVE AMPL"]
            ampl_late_ch = data_ch["LATE AMPL"]
            ampl_early_diff = ampl_early_ch/ampl_early_ref
            ampl_neg_diff = ampl_neg_ch/ampl_neg_ref
            ampl_late_diff = ampl_late_ch/ampl_late_ref
            print(time_average)
            print("--------")
            ref_FC2_dict[name][condition][ch] = {"TIME DIFF":time_diff,"TIME EARLY":round(data_ch["EARLY LATEN"], ndigits = 0),
                                                "TIME NEGATIVE":round(data_ch["NEGATIVE LATEN"]),
                                                "TIME LATE":round(data_ch["LATE LATEN"], ndigits = 0), "AMPL EARLY":ampl_early_diff, 
                                               "AMPL NEGATIVE": ampl_neg_diff, "AMPL LATE":ampl_late_diff}

# %%
#FOR FZ CHANNEL

ch_roi = []
for i in ["FC1","FC2","Cz"]:
    ch_roi.append(epoch.ch_names.index(i))
for a,b,c in os.walk("D:\epochs_4_augmentation"):
    for path in c:
        name = path.split("_")[-1].split(".")[0]
        epochs = mne.read_epochs(a+"\\"+path)
        epochs_new = []
        for num in range(len(epochs)):
            epo = epochs[num].get_data().copy()
            cond = list(epochs[num].event_id)[0]
            epo_ref = epo[0][epochs.ch_names.index("Fz")]
            epoch_after_aug = []
        #     print(epo_ref.shape)
            for chan in range(len(epochs.ch_names)):
                ch = epochs.ch_names[chan]
                ch_2_check = epochs.ch_names.index(ch)
                if ch_2_check == chan:
                    print("COOOOOOOOOOL")
                else:
                    raise "ERRROR DOLBOEB"
                info = ref_fz_dict[name][cond][ch]
                time_diff = ref_fz_dict[name][cond][ch]["TIME DIFF"]
                time_early = ref_fz_dict[name][cond][ch]["TIME EARLY"]
                time_neg = ref_fz_dict[name][cond][ch]["TIME NEGATIVE"]
                time_late = ref_fz_dict[name][cond][ch]["TIME LATE"]
                if int(time_diff)<0:
                    TAIL_BEFORE = epo_ref[-time_diff:500]
        #             print(len(TAIL_BEFORE))
                    ERP_EARLY = epo_ref[500:time_early]
        #             print(len(ERP_EARLY), time_early)
                    ERP_NEGATIVE = epo_ref[time_early:time_neg]
        #             print(len(ERP_NEGATIVE), time_neg)
                    ERP_LATE = epo_ref[time_neg:time_late]
        #             print(len(ERP_LATE), time_late)
                    TAIL_AFTER = epo_ref[time_late:]
                    TAIL_2_CONCAT = epo_ref[:-time_diff]
        #             print(len(TAIL_AFTER))
        #             print(len(TAIL_AFTER))            
                elif int(time_diff)>0:
                    TAIL_BEFORE = epo_ref[time_diff:500]
        #             print(len(TAIL_BEFORE))
                    ERP_EARLY = epo_ref[500:time_early]
        #             print(len(ERP_EARLY), time_early)
                    ERP_NEGATIVE = epo_ref[time_early:time_neg]
        #             print(len(ERP_NEGATIVE), time_neg)
                    ERP_LATE = epo_ref[time_neg:time_late]
        #             print(len(ERP_LATE), time_late)
                    TAIL_AFTER = epo_ref[time_late:]
        #             print(len(TAIL_AFTER), time_late)
                    TAIL_2_CONCAT = epo_ref[-time_diff:] 
        #             print("LEN EPO CONC", len(TAIL_2_CONCAT))
        #             print(len(TAIL_AFTER))
                else:
                    TAIL_BEFORE = epo_ref[0:500]
        #             print(len(TAIL_BEFORE))
                    ERP_EARLY = epo_ref[500:time_early]
        #             print(len(ERP_EARLY), time_early)
                    ERP_NEGATIVE = epo_ref[time_early:time_neg]
        #             print(len(ERP_NEGATIVE), time_neg)
                    ERP_LATE = epo_ref[time_neg:time_late]
        #             print(len(ERP_LATE), time_late)
                    TAIL_AFTER = epo_ref[time_late:]
        #         print("____________________")
        #         print(len(ERP_LATE)+len(ERP_NEGATIVE)+len(ERP_EARLY)+len(TAIL_BEFORE)+len(TAIL_AFTER))
        #         print("====================")
                if info["AMPL EARLY"] >2:
                    ERP_EARLY = ERP_EARLY*2
                else:
                    ERP_EARLY = ERP_EARLY*info["AMPL EARLY"]
                if info["AMPL NEGATIVE"] >2:
                    ERP_NEGATIVE = ERP_NEGATIVE*2
                else:
                    ERP_NEGATIVE = ERP_NEGATIVE*info["AMPL NEGATIVE"]
                if info["AMPL LATE"] >2:
                    ERP_LATE = ERP_LATE*2
                else:
                    ERP_LATE = ERP_LATE*info["AMPL LATE"]
                mean = np.median([info["AMPL EARLY"], info["AMPL LATE"], info["AMPL NEGATIVE"]])
                TAIL_AFTER = TAIL_AFTER*mean
                TAIL_BEFORE = TAIL_BEFORE*mean
                if time_diff>0:
                    new_epo = np.concatenate([TAIL_2_CONCAT, TAIL_BEFORE, ERP_EARLY, ERP_NEGATIVE, ERP_LATE, TAIL_AFTER])
        #             print(time_diff, "NOT COOL")
                elif time_diff<0:
                    new_epo = np.concatenate([TAIL_BEFORE, ERP_EARLY, ERP_NEGATIVE, ERP_LATE, TAIL_AFTER, TAIL_2_CONCAT])
        #             print(time_diff, "NOT COOL")
                else:
                    new_epo = np.concatenate([TAIL_BEFORE, ERP_EARLY, ERP_NEGATIVE, ERP_LATE, TAIL_AFTER])
        #             print(time_diff, "NOT COOL")
        #         print(len(new_epo))
                if len(new_epo) !=2001:
                    raise ERROR
                epoch_after_aug.append(new_epo)
            mean_Fz = []
            for index in ch_roi:
                mean_Fz.append(epoch_after_aug[index])
            mean_Fz = np.median(mean_Fz, axis = 0)
            epoch_after_aug[epochs.ch_names.index("Fz")] = mean_Fz
            print(mean_Fz)

            print(len(epoch_after_aug))
            epochs_new.append(epoch_after_aug)
        epochs_new = mne.EpochsArray(epochs_new, epochs.info, tmin = -1.0, events = epochs.events, event_id=epochs.event_id,
                                    baseline=(-1.0,0.0))
        epochs_new.save(f"D:\epochs_after_augmentation\ch_Fz_ref\\subj_{name}_ref_Fz.fif")

# %%
#FOR CZ CHANNEL
ch_roi = []
for i in ["FC1","FC2","Fz"]:
    ch_roi.append(epoch.ch_names.index(i))
for a,b,c in os.walk("D:\epochs_4_augmentation"):
    for path in c:
        name = path.split("_")[-1].split(".")[0]
        epochs = mne.read_epochs(a+"\\"+path)
        epochs_new = []
        for num in range(len(epochs)):
            epo = epochs[num].get_data().copy()
            cond = list(epochs[num].event_id)[0]
            epo_ref = epo[0][epochs.ch_names.index("Cz")]
            epoch_after_aug = []
        #     print(epo_ref.shape)
            for chan in range(len(epochs.ch_names)):
                ch = epochs.ch_names[chan]
                ch_2_check = epochs.ch_names.index(ch)
                if ch_2_check == chan:
                    print("COOOOOOOOOOL")
                else:
                    raise "ERRROR DOLBOEB"
                info = ref_cz_dict[name][cond][ch]
                time_diff = ref_cz_dict[name][cond][ch]["TIME DIFF"]
                time_early = ref_cz_dict[name][cond][ch]["TIME EARLY"]
                time_neg = ref_cz_dict[name][cond][ch]["TIME NEGATIVE"]
                time_late = ref_cz_dict[name][cond][ch]["TIME LATE"]
                if int(time_diff)<0:
                    TAIL_BEFORE = epo_ref[-time_diff:500]
        #             print(len(TAIL_BEFORE))
                    ERP_EARLY = epo_ref[500:time_early]
        #             print(len(ERP_EARLY), time_early)
                    ERP_NEGATIVE = epo_ref[time_early:time_neg]
        #             print(len(ERP_NEGATIVE), time_neg)
                    ERP_LATE = epo_ref[time_neg:time_late]
        #             print(len(ERP_LATE), time_late)
                    TAIL_AFTER = epo_ref[time_late:]
                    TAIL_2_CONCAT = epo_ref[:-time_diff]
        #             print(len(TAIL_AFTER))
        #             print(len(TAIL_AFTER))            
                elif int(time_diff)>0:
                    TAIL_BEFORE = epo_ref[time_diff:500]
        #             print(len(TAIL_BEFORE))
                    ERP_EARLY = epo_ref[500:time_early]
        #             print(len(ERP_EARLY), time_early)
                    ERP_NEGATIVE = epo_ref[time_early:time_neg]
        #             print(len(ERP_NEGATIVE), time_neg)
                    ERP_LATE = epo_ref[time_neg:time_late]
        #             print(len(ERP_LATE), time_late)
                    TAIL_AFTER = epo_ref[time_late:]
        #             print(len(TAIL_AFTER), time_late)
                    TAIL_2_CONCAT = epo_ref[-time_diff:] 
        #             print("LEN EPO CONC", len(TAIL_2_CONCAT))
        #             print(len(TAIL_AFTER))
                else:
                    TAIL_BEFORE = epo_ref[0:500]
        #             print(len(TAIL_BEFORE))
                    ERP_EARLY = epo_ref[500:time_early]
        #             print(len(ERP_EARLY), time_early)
                    ERP_NEGATIVE = epo_ref[time_early:time_neg]
        #             print(len(ERP_NEGATIVE), time_neg)
                    ERP_LATE = epo_ref[time_neg:time_late]
        #             print(len(ERP_LATE), time_late)
                    TAIL_AFTER = epo_ref[time_late:]
        #         print("____________________")
        #         print(len(ERP_LATE)+len(ERP_NEGATIVE)+len(ERP_EARLY)+len(TAIL_BEFORE)+len(TAIL_AFTER))
        #         print("====================")
                if info["AMPL EARLY"] >2:
                    ERP_EARLY = ERP_EARLY*2
                else:
                    ERP_EARLY = ERP_EARLY*info["AMPL EARLY"]
                if info["AMPL NEGATIVE"] >2:
                    ERP_NEGATIVE = ERP_NEGATIVE*2
                else:
                    ERP_NEGATIVE = ERP_NEGATIVE*info["AMPL NEGATIVE"]
                if info["AMPL LATE"] >2:
                    ERP_LATE = ERP_LATE*2
                else:
                    ERP_LATE = ERP_LATE*info["AMPL LATE"]
                mean = np.median([info["AMPL EARLY"], info["AMPL LATE"], info["AMPL NEGATIVE"]])
                TAIL_AFTER = TAIL_AFTER*mean
                TAIL_BEFORE = TAIL_BEFORE*mean
                if time_diff>0:
                    new_epo = np.concatenate([TAIL_2_CONCAT, TAIL_BEFORE, ERP_EARLY, ERP_NEGATIVE, ERP_LATE, TAIL_AFTER])
        #             print(time_diff, "NOT COOL")
                elif time_diff<0:
                    new_epo = np.concatenate([TAIL_BEFORE, ERP_EARLY, ERP_NEGATIVE, ERP_LATE, TAIL_AFTER, TAIL_2_CONCAT])
        #             print(time_diff, "NOT COOL")
                else:
                    new_epo = np.concatenate([TAIL_BEFORE, ERP_EARLY, ERP_NEGATIVE, ERP_LATE, TAIL_AFTER])
        #             print(time_diff, "NOT COOL")
        #         print(len(new_epo))
                if len(new_epo) !=2001:
                    raise ERROR
                epoch_after_aug.append(new_epo)
            mean_cz = []
            for index in ch_roi:
                mean_cz.append(epoch_after_aug[index])
            mean_cz = np.median(mean_cz, axis = 0)
            epoch_after_aug[epochs.ch_names.index("Cz")] = mean_cz
            print(mean_cz)

            print(len(epoch_after_aug))
            epochs_new.append(epoch_after_aug)
        epochs_new = mne.EpochsArray(epochs_new, epochs.info, tmin = -1.0, events = epochs.events, event_id=epochs.event_id,
                                    baseline=(-1.0,0.0))
        epochs_new.save(f"D:\epochs_after_augmentation\ch_Cz_ref\\subj_{name}_ref_Cz.fif")

# %%
#FOR PZ CHANNEL
ch_roi = []
for i in ["P3", "P4", "Cz"]:
    ch_roi.append(epoch.ch_names.index(i))
for a,b,c in os.walk("D:\epochs_4_augmentation"):
    for path in c:
        name = path.split("_")[-1].split(".")[0]
        epochs = mne.read_epochs(a+"\\"+path)
        epochs_new = []
        for num in range(len(epochs)):
            epo = epochs[num].get_data().copy()
            cond = list(epochs[num].event_id)[0]
            epo_ref = epo[0][epochs.ch_names.index("Pz")]
            epoch_after_aug = []
        #     print(epo_ref.shape)
            for chan in range(len(epochs.ch_names)):
                ch = epochs.ch_names[chan]
                ch_2_check = epochs.ch_names.index(ch)
                if ch_2_check == chan:
                    print("COOOOOOOOOOL")
                else:
                    raise "ERRROR DOLBOEB"
                info = ref_pz_dict[name][cond][ch]
                time_diff = ref_pz_dict[name][cond][ch]["TIME DIFF"]
                time_early = ref_pz_dict[name][cond][ch]["TIME EARLY"]
                time_neg = ref_pz_dict[name][cond][ch]["TIME NEGATIVE"]
                time_late = ref_pz_dict[name][cond][ch]["TIME LATE"]
                if int(time_diff)<0:
                    TAIL_BEFORE = epo_ref[-time_diff:500]
        #             print(len(TAIL_BEFORE))
                    ERP_EARLY = epo_ref[500:time_early]
        #             print(len(ERP_EARLY), time_early)
                    ERP_NEGATIVE = epo_ref[time_early:time_neg]
        #             print(len(ERP_NEGATIVE), time_neg)
                    ERP_LATE = epo_ref[time_neg:time_late]
        #             print(len(ERP_LATE), time_late)
                    TAIL_AFTER = epo_ref[time_late:]
                    TAIL_2_CONCAT = epo_ref[:-time_diff]
        #             print(len(TAIL_AFTER))
        #             print(len(TAIL_AFTER))            
                elif int(time_diff)>0:
                    TAIL_BEFORE = epo_ref[time_diff:500]
        #             print(len(TAIL_BEFORE))
                    ERP_EARLY = epo_ref[500:time_early]
        #             print(len(ERP_EARLY), time_early)
                    ERP_NEGATIVE = epo_ref[time_early:time_neg]
        #             print(len(ERP_NEGATIVE), time_neg)
                    ERP_LATE = epo_ref[time_neg:time_late]
        #             print(len(ERP_LATE), time_late)
                    TAIL_AFTER = epo_ref[time_late:]
        #             print(len(TAIL_AFTER), time_late)
                    TAIL_2_CONCAT = epo_ref[-time_diff:] 
        #             print("LEN EPO CONC", len(TAIL_2_CONCAT))
        #             print(len(TAIL_AFTER))
                else:
                    TAIL_BEFORE = epo_ref[0:500]
        #             print(len(TAIL_BEFORE))
                    ERP_EARLY = epo_ref[500:time_early]
        #             print(len(ERP_EARLY), time_early)
                    ERP_NEGATIVE = epo_ref[time_early:time_neg]
        #             print(len(ERP_NEGATIVE), time_neg)
                    ERP_LATE = epo_ref[time_neg:time_late]
        #             print(len(ERP_LATE), time_late)
                    TAIL_AFTER = epo_ref[time_late:]
        #         print("____________________")
        #         print(len(ERP_LATE)+len(ERP_NEGATIVE)+len(ERP_EARLY)+len(TAIL_BEFORE)+len(TAIL_AFTER))
        #         print("====================")
                if info["AMPL EARLY"] >2:
                    ERP_EARLY = ERP_EARLY*2
                else:
                    ERP_EARLY = ERP_EARLY*info["AMPL EARLY"]
                if info["AMPL NEGATIVE"] >2:
                    ERP_NEGATIVE = ERP_NEGATIVE*2
                else:
                    ERP_NEGATIVE = ERP_NEGATIVE*info["AMPL NEGATIVE"]
                if info["AMPL LATE"] >2:
                    ERP_LATE = ERP_LATE*2
                else:
                    ERP_LATE = ERP_LATE*info["AMPL LATE"]
                mean = np.median([info["AMPL EARLY"], info["AMPL LATE"], info["AMPL NEGATIVE"]])
                TAIL_AFTER = TAIL_AFTER*mean
                TAIL_BEFORE = TAIL_BEFORE*mean
                if time_diff>0:
                    new_epo = np.concatenate([TAIL_2_CONCAT, TAIL_BEFORE, ERP_EARLY, ERP_NEGATIVE, ERP_LATE, TAIL_AFTER])
        #             print(time_diff, "NOT COOL")
                elif time_diff<0:
                    new_epo = np.concatenate([TAIL_BEFORE, ERP_EARLY, ERP_NEGATIVE, ERP_LATE, TAIL_AFTER, TAIL_2_CONCAT])
        #             print(time_diff, "NOT COOL")
                else:
                    new_epo = np.concatenate([TAIL_BEFORE, ERP_EARLY, ERP_NEGATIVE, ERP_LATE, TAIL_AFTER])
        #             print(time_diff, "NOT COOL")
        #         print(len(new_epo))
                if len(new_epo) !=2001:
                    raise ERROR
                epoch_after_aug.append(new_epo)
            mean_pz = []
            for index in ch_roi:
                mean_pz.append(epoch_after_aug[index])
            mean_pz = np.median(mean_pz, axis = 0)
            epoch_after_aug[epochs.ch_names.index("Pz")] = mean_pz
            print(mean_pz)

            print(len(epoch_after_aug))
            epochs_new.append(epoch_after_aug)
        epochs_new = mne.EpochsArray(epochs_new, epochs.info, tmin = -1.0, events = epochs.events, event_id=epochs.event_id,
                                    baseline=(-1.0,0.0))
        epochs_new.save(f"D:\epochs_after_augmentation\ch_Pz_ref\\subj_{name}_ref_Pz.fif")

# %%
#FOR FC1 CHANNEL
ch_roi = []
for i in ["F3", "Fz", "Cz"]:
    ch_roi.append(epoch.ch_names.index(i))
for a,b,c in os.walk("D:\epochs_4_augmentation"):
    for path in c:
        name = path.split("_")[-1].split(".")[0]
        epochs = mne.read_epochs(a+"\\"+path)
        epochs_new = []
        for num in range(len(epochs)):
            epo = epochs[num].get_data().copy()
            cond = list(epochs[num].event_id)[0]
            epo_ref = epo[0][epochs.ch_names.index("FC1")]
            epoch_after_aug = []
        #     print(epo_ref.shape)
            for chan in range(len(epochs.ch_names)):
                ch = epochs.ch_names[chan]
                ch_2_check = epochs.ch_names.index(ch)
                if ch_2_check == chan:
                    print("COOOOOOOOOOL")
                else:
                    raise "ERRROR DOLBOEB"
                info = ref_FC1_dict[name][cond][ch]
                time_diff = ref_FC1_dict[name][cond][ch]["TIME DIFF"]
                time_early = ref_FC1_dict[name][cond][ch]["TIME EARLY"]
                time_neg = ref_FC1_dict[name][cond][ch]["TIME NEGATIVE"]
                time_late = ref_FC1_dict[name][cond][ch]["TIME LATE"]
                if int(time_diff)<0:
                    TAIL_BEFORE = epo_ref[-time_diff:500]
        #             print(len(TAIL_BEFORE))
                    ERP_EARLY = epo_ref[500:time_early]
        #             print(len(ERP_EARLY), time_early)
                    ERP_NEGATIVE = epo_ref[time_early:time_neg]
        #             print(len(ERP_NEGATIVE), time_neg)
                    ERP_LATE = epo_ref[time_neg:time_late]
        #             print(len(ERP_LATE), time_late)
                    TAIL_AFTER = epo_ref[time_late:]
                    TAIL_2_CONCAT = epo_ref[:-time_diff]
        #             print(len(TAIL_AFTER))
        #             print(len(TAIL_AFTER))            
                elif int(time_diff)>0:
                    TAIL_BEFORE = epo_ref[time_diff:500]
        #             print(len(TAIL_BEFORE))
                    ERP_EARLY = epo_ref[500:time_early]
        #             print(len(ERP_EARLY), time_early)
                    ERP_NEGATIVE = epo_ref[time_early:time_neg]
        #             print(len(ERP_NEGATIVE), time_neg)
                    ERP_LATE = epo_ref[time_neg:time_late]
        #             print(len(ERP_LATE), time_late)
                    TAIL_AFTER = epo_ref[time_late:]
        #             print(len(TAIL_AFTER), time_late)
                    TAIL_2_CONCAT = epo_ref[-time_diff:] 
        #             print("LEN EPO CONC", len(TAIL_2_CONCAT))
        #             print(len(TAIL_AFTER))
                else:
                    TAIL_BEFORE = epo_ref[0:500]
        #             print(len(TAIL_BEFORE))
                    ERP_EARLY = epo_ref[500:time_early]
        #             print(len(ERP_EARLY), time_early)
                    ERP_NEGATIVE = epo_ref[time_early:time_neg]
        #             print(len(ERP_NEGATIVE), time_neg)
                    ERP_LATE = epo_ref[time_neg:time_late]
        #             print(len(ERP_LATE), time_late)
                    TAIL_AFTER = epo_ref[time_late:]
        #         print("____________________")
        #         print(len(ERP_LATE)+len(ERP_NEGATIVE)+len(ERP_EARLY)+len(TAIL_BEFORE)+len(TAIL_AFTER))
        #         print("====================")
                if info["AMPL EARLY"] >2:
                    ERP_EARLY = ERP_EARLY*2
                else:
                    ERP_EARLY = ERP_EARLY*info["AMPL EARLY"]
                if info["AMPL NEGATIVE"] >2:
                    ERP_NEGATIVE = ERP_NEGATIVE*2
                else:
                    ERP_NEGATIVE = ERP_NEGATIVE*info["AMPL NEGATIVE"]
                if info["AMPL LATE"] >2:
                    ERP_LATE = ERP_LATE*2
                else:
                    ERP_LATE = ERP_LATE*info["AMPL LATE"]
                mean = np.median([info["AMPL EARLY"], info["AMPL LATE"], info["AMPL NEGATIVE"]])
                TAIL_AFTER = TAIL_AFTER*mean
                TAIL_BEFORE = TAIL_BEFORE*mean
                if time_diff>0:
                    new_epo = np.concatenate([TAIL_2_CONCAT, TAIL_BEFORE, ERP_EARLY, ERP_NEGATIVE, ERP_LATE, TAIL_AFTER])
        #             print(time_diff, "NOT COOL")
                elif time_diff<0:
                    new_epo = np.concatenate([TAIL_BEFORE, ERP_EARLY, ERP_NEGATIVE, ERP_LATE, TAIL_AFTER, TAIL_2_CONCAT])
        #             print(time_diff, "NOT COOL")
                else:
                    new_epo = np.concatenate([TAIL_BEFORE, ERP_EARLY, ERP_NEGATIVE, ERP_LATE, TAIL_AFTER])
        #             print(time_diff, "NOT COOL")
        #         print(len(new_epo))
                if len(new_epo) !=2001:
                    raise ERROR
                epoch_after_aug.append(new_epo)
            mean_FC1 = []
            for index in ch_roi:
                mean_FC1.append(epoch_after_aug[index])
            mean_FC1 = np.median(mean_FC1, axis = 0)
            epoch_after_aug[epochs.ch_names.index("FC1")] = mean_FC1
            print(mean_FC1)

            print(len(epoch_after_aug))
            epochs_new.append(epoch_after_aug)
        epochs_new = mne.EpochsArray(epochs_new, epochs.info, tmin = -1.0, events = epochs.events, event_id=epochs.event_id,
                                    baseline=(-1.0,0.0))
        epochs_new.save(f"D:\epochs_after_augmentation\ch_FC1_ref\\subj_{name}_ref_FC1.fif")

# %%
#FOR FC2 CHANNEL
ch_roi = []
for i in ["F4", "Fz", "Cz"]:
    ch_roi.append(epoch.ch_names.index(i))
for a,b,c in os.walk("D:\epochs_4_augmentation"):
    for path in c:
        name = path.split("_")[-1].split(".")[0]
        epochs = mne.read_epochs(a+"\\"+path)
        epochs_new = []
        for num in range(len(epochs)):
            epo = epochs[num].get_data().copy()
            cond = list(epochs[num].event_id)[0]
            epo_ref = epo[0][epochs.ch_names.index("FC2")]
            epoch_after_aug = []
        #     print(epo_ref.shape)
            for chan in range(len(epochs.ch_names)):
                ch = epochs.ch_names[chan]
                ch_2_check = epochs.ch_names.index(ch)
                if ch_2_check == chan:
                    print("COOOOOOOOOOL")
                else:
                    raise "ERRROR DOLBOEB"
                info = ref_FC2_dict[name][cond][ch]
                time_diff = ref_FC2_dict[name][cond][ch]["TIME DIFF"]
                time_early = ref_FC2_dict[name][cond][ch]["TIME EARLY"]
                time_neg = ref_FC2_dict[name][cond][ch]["TIME NEGATIVE"]
                time_late = ref_FC2_dict[name][cond][ch]["TIME LATE"]
                if int(time_diff)<0:
                    TAIL_BEFORE = epo_ref[-time_diff:500]
        #             print(len(TAIL_BEFORE))
                    ERP_EARLY = epo_ref[500:time_early]
        #             print(len(ERP_EARLY), time_early)
                    ERP_NEGATIVE = epo_ref[time_early:time_neg]
        #             print(len(ERP_NEGATIVE), time_neg)
                    ERP_LATE = epo_ref[time_neg:time_late]
        #             print(len(ERP_LATE), time_late)
                    TAIL_AFTER = epo_ref[time_late:]
                    TAIL_2_CONCAT = epo_ref[:-time_diff]
        #             print(len(TAIL_AFTER))
        #             print(len(TAIL_AFTER))            
                elif int(time_diff)>0:
                    TAIL_BEFORE = epo_ref[time_diff:500]
        #             print(len(TAIL_BEFORE))
                    ERP_EARLY = epo_ref[500:time_early]
        #             print(len(ERP_EARLY), time_early)
                    ERP_NEGATIVE = epo_ref[time_early:time_neg]
        #             print(len(ERP_NEGATIVE), time_neg)
                    ERP_LATE = epo_ref[time_neg:time_late]
        #             print(len(ERP_LATE), time_late)
                    TAIL_AFTER = epo_ref[time_late:]
        #             print(len(TAIL_AFTER), time_late)
                    TAIL_2_CONCAT = epo_ref[-time_diff:] 
        #             print("LEN EPO CONC", len(TAIL_2_CONCAT))
        #             print(len(TAIL_AFTER))
                else:
                    TAIL_BEFORE = epo_ref[0:500]
        #             print(len(TAIL_BEFORE))
                    ERP_EARLY = epo_ref[500:time_early]
        #             print(len(ERP_EARLY), time_early)
                    ERP_NEGATIVE = epo_ref[time_early:time_neg]
        #             print(len(ERP_NEGATIVE), time_neg)
                    ERP_LATE = epo_ref[time_neg:time_late]
        #             print(len(ERP_LATE), time_late)
                    TAIL_AFTER = epo_ref[time_late:]
        #         print("____________________")
        #         print(len(ERP_LATE)+len(ERP_NEGATIVE)+len(ERP_EARLY)+len(TAIL_BEFORE)+len(TAIL_AFTER))
        #         print("====================")
                if info["AMPL EARLY"] >2:
                    ERP_EARLY = ERP_EARLY*2
                else:
                    ERP_EARLY = ERP_EARLY*info["AMPL EARLY"]
                if info["AMPL NEGATIVE"] >2:
                    ERP_NEGATIVE = ERP_NEGATIVE*2
                else:
                    ERP_NEGATIVE = ERP_NEGATIVE*info["AMPL NEGATIVE"]
                if info["AMPL LATE"] >2:
                    ERP_LATE = ERP_LATE*2
                else:
                    ERP_LATE = ERP_LATE*info["AMPL LATE"]
                mean = np.median([info["AMPL EARLY"], info["AMPL LATE"], info["AMPL NEGATIVE"]])
                TAIL_AFTER = TAIL_AFTER*mean
                TAIL_BEFORE = TAIL_BEFORE*mean
                if time_diff>0:
                    new_epo = np.concatenate([TAIL_2_CONCAT, TAIL_BEFORE, ERP_EARLY, ERP_NEGATIVE, ERP_LATE, TAIL_AFTER])
        #             print(time_diff, "NOT COOL")
                elif time_diff<0:
                    new_epo = np.concatenate([TAIL_BEFORE, ERP_EARLY, ERP_NEGATIVE, ERP_LATE, TAIL_AFTER, TAIL_2_CONCAT])
        #             print(time_diff, "NOT COOL")
                else:
                    new_epo = np.concatenate([TAIL_BEFORE, ERP_EARLY, ERP_NEGATIVE, ERP_LATE, TAIL_AFTER])
        #             print(time_diff, "NOT COOL")
        #         print(len(new_epo))
                if len(new_epo) !=2001:
                    raise ERROR
                epoch_after_aug.append(new_epo)
            mean_FC2 = []
            for index in ch_roi:
                mean_FC2.append(epoch_after_aug[index])
            mean_FC2 = np.median(mean_FC2, axis = 0)
            epoch_after_aug[epochs.ch_names.index("FC2")] = mean_FC2
            print(mean_FC2)

            print(len(epoch_after_aug))
            epochs_new.append(epoch_after_aug)
        epochs_new = mne.EpochsArray(epochs_new, epochs.info, tmin = -1.0, events = epochs.events, event_id=epochs.event_id,
                                    baseline=(-1.0,0.0))
        epochs_new.save(f"D:\epochs_after_augmentation\ch_FC2_ref\\subj_{name}_ref_FC2.fif")

# %%
epochs_fz = mne.read_epochs(r"D:\epochs_after_augmentation\ch_Fz_ref\subj_15_ref_Fz.fif", preload = True)
epochs_cz = mne.read_epochs(r"D:\epochs_after_augmentation\ch_Cz_ref\subj_15_ref_Cz.fif", preload = True)
epochs_pz = mne.read_epochs(r"D:\epochs_after_augmentation\ch_Pz_ref\subj_15_ref_Pz.fif", preload = True)
epochs_fc1 = mne.read_epochs(r"D:\epochs_after_augmentation\ch_FC1_ref\subj_15_ref_FC1.fif", preload = True)
epochs_fc2 = mne.read_epochs(r"D:\epochs_after_augmentation\ch_FC2_ref\subj_15_ref_FC2.fif", preload = True)
epochs_orig = mne.read_epochs(r"D:\epochs_4_augmentation\subj_15.fif", preload = True)
evoked_fz = {c:epochs_fz[c].filter(1,10).crop(-0.3,0.8).average() for c in conditions}
evoked_cz = {c:epochs_cz[c].filter(1,10).crop(-0.3,0.8).average() for c in conditions}
evoked_pz = {c:epochs_pz[c].filter(1,10).crop(-0.3,0.8).average() for c in conditions}
evoked_fc1 = {c:epochs_fc1[c].filter(1,10).crop(-0.3,0.8).average() for c in conditions}
evoked_fc2 = {c:epochs_fc2[c].filter(1,10).crop(-0.3,0.8).average() for c in conditions}
evoked_orig = {c:epochs_orig[c].filter(1,10).crop(-0.3,0.8).average() for c in conditions}

# %%
evoked_dict = {"Ref FZ AUG":evoked_fz["no"], "Ref CZ AUG":evoked_cz["no"], "Ref PZ AUG":evoked_pz["no"],
               "Ref FC1 AUG":evoked_fc1["no"], "Ref PZ AUG":evoked_fc2["no"],"NO AUG":evoked_orig["no"]}

# %%
mne.viz.plot_compare_evokeds(evoked_dict, picks = ["Fz", "Cz", "FC1", "FC2"], combine = "mean")
